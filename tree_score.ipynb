# %%
import pandas as pd
from thefuzz import process

# %%
tree_data = pd.read_excel('tree_data.xlsx')
la_trees_fire_temp = pd.read_csv('la_trees_fire_temp.csv')

# %%
def match_tree_name(name, choices, threshold=80):
    """Fuzzy match a name to a list of choices with a threshold."""
    if pd.isna(name):
        return None
    match, score = process.extractOne(name, choices)
    return match if score >= threshold else None

def match_treegroup_name(name, choices, threshold=65):
    """Fuzzy match a TreeGroup name to a list of choices with a lower threshold."""
    if pd.isna(name):
        return None
    name = name.lower().strip()
    choices = [c.lower().strip() for c in choices]
    match, score = process.extractOne(name, choices)
    return match if score >= threshold else None

# %%
# Get unique tree names from tree_data
tree_names = tree_data['Common Name'].unique()

# Match each name in la_trees_fire_temp to the closest in tree_data
la_trees_fire_temp['Matched Tree Name'] = la_trees_fire_temp['Species'].apply(
    lambda x: match_tree_name(x, tree_names)
)

# %%
# Merge Firewise Rating using the matched names
merged = la_trees_fire_temp.merge(
    tree_data[['Common Name', 'Firewise Rating']],
    left_on='Matched Tree Name',
    right_on='Common Name',
    how='left'
)

# %%
merged
# Out:
#         Latitude   Longitude                               Species   DBH  \
# 0      34.154814 -118.589896    coast live oak (Quercus agrifolia)  25.0
# 1      34.154815 -118.589929    coast live oak (Quercus agrifolia)  13.0
# 2      34.275480 -118.541392         MyLA311 Added (MyLA311 Added)   0.0
# 3      34.145944 -118.505713         MyLA311 Added (MyLA311 Added)   0.0
# 4      34.089382 -118.452487    coast live oak (Quercus agrifolia)  10.0
# ...          ...         ...                                   ...   ...
# 51920  34.281985 -118.524873  swamp mallee (Eucalyptus spathulata)   1.0
# 51921  34.281909 -118.524855              cork oak (Quercus suber)   1.0
# 51922  34.281829 -118.524832              cork oak (Quercus suber)   1.0
# 51923  34.281753 -118.524804              cork oak (Quercus suber)   1.0
# 51924  34.281672 -118.524785              cork oak (Quercus suber)   1.0
#
#        Any_Protected  tree_id                                       geometry  \
# 0              False      398  POINT (-118.58989569441763 34.15481399358518)
# 1              False      399  POINT (-118.5899292220234 34.154815103381026)
# 2              False      782  POINT (-118.54139204162942 34.27547960352691)
# 3              False     1620  POINT (-118.50571275517476 34.14594381558009)
# 4              False     1826  POINT (-118.4524866762754 34.089381786916896)
# ...              ...      ...                                            ...
# 51920          False   848183       POINT (-118.52487262848 34.281985493955)
# 51921          False   848184       POINT (-118.52485539633 34.281909200602)
# 51922          False   848185      POINT (-118.524831927001 34.281829415729)
# 51923          False   848186      POINT (-118.524804103646 34.281752631767)
# 51924          False   848187      POINT (-118.524785328183 34.281672292682)
#
#        index_right  OBJECTID   YEAR_  ...   Shape__Area Shape__Length  \
# 0            18162     18164  1944.0  ...  2.694018e+07  35271.399924
# 1            18162     18164  1944.0  ...  2.694018e+07  35271.399924
# 2            15796     15798  1959.0  ...  3.709861e+06   8002.545419
# 3            15672     15674  1960.0  ...  4.783674e+05   4025.625330
# 4            15424     15426  1961.0  ...  3.640036e+07  48599.914373
# ...            ...       ...     ...  ...           ...           ...
# 51920        17825     17827  1947.0  ...  2.472436e+06   7602.760800
# 51921        17825     17827  1947.0  ...  2.472436e+06   7602.760800
# 51922        17825     17827  1947.0  ...  2.472436e+06   7602.760800
# 51923        17825     17827  1947.0  ...  2.472436e+06   7602.760800
# 51924        17825     17827  1947.0  ...  2.472436e+06   7602.760800
#
#       tree_appear_count FIRE_SIZE_CATEGORY  USDA_FIRE_SIZE_CLASS   TreeGroup  \
# 0                     1              Large             F - Large         Oak
# 1                     1              Large             F - Large         Oak
# 2                     2             Medium            E - Medium     Myla311
# 3                     1              Small             C - Small     Myla311
# 4                     1              Large             G - Large         Oak
# ...                 ...                ...                   ...         ...
# 51920                 1             Medium            E - Medium  Eucalyptus
# 51921                 1             Medium            E - Medium         Oak
# 51922                 1             Medium            E - Medium         Oak
# 51923                 1             Medium            E - Medium         Oak
# 51924                 1             Medium            E - Medium         Oak
#
#       Annual_Temp  Matched Tree Name  Common Name       Firewise Rating
# 0            62.2           live oak     live oak  AT RISK Firewise (3)
# 1            62.2           live oak     live oak  AT RISK Firewise (3)
# 2            67.3               None          NaN                   NaN
# 3            65.6               None          NaN                   NaN
# 4            65.3           live oak     live oak  AT RISK Firewise (3)
# ...           ...                ...          ...                   ...
# 51920        64.1         eucalyptus   eucalyptus      NOT Firewise (4)
# 51921        64.1          black oak    black oak          Firewise (1)
# 51922        64.1          black oak    black oak          Firewise (1)
# 51923        64.1          black oak    black oak          Firewise (1)
# 51924        64.1          black oak    black oak          Firewise (1)
#
# [51925 rows x 27 columns]

# %%
# Find rows where Firewise Rating is NaN
nan_rows = merged[merged['Firewise Rating'].isna()].copy()

# Try to match TreeGroup to Common Name for these rows (lower threshold)
nan_rows['Matched TreeGroup Name'] = nan_rows['TreeGroup'].apply(
    lambda x: match_treegroup_name(x, tree_names, threshold=65)
)

# Merge again to get Firewise Rating using the new matches
nan_rows = nan_rows.merge(
    tree_data[['Common Name', 'Firewise Rating']],
    left_on='Matched TreeGroup Name',
    right_on='Common Name',
    how='left',
    suffixes=('', '_TreeGroup')
)

# %%
# Update merged Firewise Rating where possible
for idx, row in nan_rows.iterrows():
    if pd.notna(row['Firewise Rating_TreeGroup']):
        merged.loc[idx, 'Firewise Rating'] = row['Firewise Rating_TreeGroup']

# %%
# Show unique TreeGroup values where Firewise Rating is still NaN
unmatched_treegroups = merged[merged['Firewise Rating'].isna()]['TreeGroup'].unique()
print(unmatched_treegroups)
# Out:
# ['Myla311' 'Jacaranda' 'Cupaniopsis' 'Bignoniaceae' 'Psidium'
#  'Lophostemon' 'Persea' 'Fig' 'Melaleuca' 'Ceratonia' 'Heteromeles'
#  'Pithecellobium' 'Tipuana' 'Acacia' 'Erythrina' 'Prunus' 'Eucalyptus'
#  'Parkinsonia' 'Xylosma' 'Citrus' 'Lyonothamnus' 'Koelreuteria'
#  'Araucaria']

# %%
# Assign Firewise Rating for TreeGroup 'Persea' where missing
merged.loc[
    (merged['TreeGroup'] == 'Persea') & (merged['Firewise Rating'].isna()),
    'Firewise Rating'
] = 'AT RISK Firewise (3)'

# %%
# Assign Firewise Rating for TreeGroup 'Fig' where missing
merged.loc[
    (merged['TreeGroup'] == 'Fig') & (merged['Firewise Rating'].isna()),
    'Firewise Rating'
] = 'MODERATELY Firewise (2)'

# %%
# Assign Firewise Rating for TreeGroup 'Acacia' where missing
merged.loc[
    (merged['TreeGroup'] == 'Acacia') & (merged['Firewise Rating'].isna()),
    'Firewise Rating'
] = 'MODERATELY Firewise (2)'

# %%
# Assign Firewise Rating for TreeGroup 'Prunus' where missing
merged.loc[
    (merged['TreeGroup'] == 'Prunus') & (merged['Firewise Rating'].isna()),
    'Firewise Rating'
] = 'MODERATELY Firewise (2)'

# %%
# Assign Firewise Rating for TreeGroup 'Eucalyptus' where missing
merged.loc[
    (merged['TreeGroup'] == 'Eucalyptus') & (merged['Firewise Rating'].isna()),
    'Firewise Rating'
] = 'NOT Firewise (4)'

# %%
# Assign Firewise Rating for TreeGroup 'Citrus' where missing
merged.loc[
    (merged['TreeGroup'] == 'Citrus') & (merged['Firewise Rating'].isna()),
    'Firewise Rating'
] = 'AT RISK Firewise (3)'

# %%
# Assign Firewise Rating for TreeGroup 'Koelreuteria' where missing
merged.loc[
    (merged['TreeGroup'] == 'Koelreuteria') & (merged['Firewise Rating'].isna()),
    'Firewise Rating'
] = 'Firewise (1)'

# %%
merged[merged['Firewise Rating'].isna()]
# Out:
#         Latitude   Longitude  \
# 2      34.275480 -118.541392
# 3      34.145944 -118.505713
# 7      34.132728 -118.478920
# 9      34.132561 -118.478953
# 52     34.139447 -118.527297
# ...          ...         ...
# 51694  34.288939 -118.556508
# 51695  34.288917 -118.556413
# 51696  34.288815 -118.556424
# 51711  34.289441 -118.556775
# 51784  34.130965 -118.207077
#
#                                                 Species   DBH  Any_Protected  \
# 2                         MyLA311 Added (MyLA311 Added)   0.0          False
# 3                         MyLA311 Added (MyLA311 Added)   0.0          False
# 7                     jacaranda (Jacaranda mimosifolia)  11.0          False
# 9                     jacaranda (Jacaranda mimosifolia)  22.0          False
# 52               carrotwood (Cupaniopsis anacardioides)   3.0          False
# ...                                                 ...   ...            ...
# 51694                 jacaranda (Jacaranda mimosifolia)   5.0          False
# 51695                 jacaranda (Jacaranda mimosifolia)   8.0          False
# 51696                 jacaranda (Jacaranda mimosifolia)   5.0          False
# 51711                 jacaranda (Jacaranda mimosifolia)  10.0          False
# 51784  toyon; Christmas berry (Heteromeles arbutifolia)   8.0          False
#
#        tree_id                                       geometry  index_right  \
# 2          782  POINT (-118.54139204162942 34.27547960352691)        15796
# 3         1620  POINT (-118.50571275517476 34.14594381558009)        15672
# 7         2066           POINT (-118.478919571 34.1327277743)        16505
# 9         2068           POINT (-118.478953028 34.1325613221)        16505
# 52        3962           POINT (-118.527297157 34.1394474078)        18162
# ...        ...                                            ...          ...
# 51694   841405            POINT (-118.556508301 34.288939292)        17346
# 51695   841406           POINT (-118.556413467 34.2889169056)        17346
# 51696   841407           POINT (-118.556424004 34.2888149228)        17346
# 51711   841424           POINT (-118.556774908 34.2894405248)        17346
# 51784   847725           POINT (-118.207077117 34.1309645033)        12892
#
#        OBJECTID   YEAR_  ...   Shape__Area Shape__Length tree_appear_count  \
# 2         15798  1959.0  ...  3.709861e+06   8002.545419                 2
# 3         15674  1960.0  ...  4.783674e+05   4025.625330                 1
# 7         16507  1955.0  ...  7.001529e+05   6152.939792                 1
# 9         16507  1955.0  ...  7.001529e+05   6152.939792                 1
# 52        18164  1944.0  ...  2.694018e+07  35271.399924                 1
# ...         ...     ...  ...           ...           ...               ...
# 51694     17348  1950.0  ...  2.516131e+07  31893.552189                 1
# 51695     17348  1950.0  ...  2.516131e+07  31893.552189                 1
# 51696     17348  1950.0  ...  2.516131e+07  31893.552189                 1
# 51711     17348  1950.0  ...  2.516131e+07  31893.552189                 3
# 51784     12894  1979.0  ...  9.825496e+04   1347.111904                 1
#
#       FIRE_SIZE_CATEGORY  USDA_FIRE_SIZE_CLASS    TreeGroup Annual_Temp  \
# 2                 Medium            E - Medium      Myla311        67.3
# 3                  Small             C - Small      Myla311        65.6
# 7                 Medium            D - Medium    Jacaranda        63.7
# 9                 Medium            D - Medium    Jacaranda        63.7
# 52                 Large             F - Large  Cupaniopsis        62.2
# ...                  ...                   ...          ...         ...
# 51694              Large             F - Large    Jacaranda        63.8
# 51695              Large             F - Large    Jacaranda        63.8
# 51696              Large             F - Large    Jacaranda        63.8
# 51711              Large             F - Large    Jacaranda        63.8
# 51784              Small             C - Small  Heteromeles        65.4
#
#        Matched Tree Name  Common Name  Firewise Rating
# 2                   None          NaN              NaN
# 3                   None          NaN              NaN
# 7                   None          NaN              NaN
# 9                   None          NaN              NaN
# 52                  None          NaN              NaN
# ...                  ...          ...              ...
# 51694               None          NaN              NaN
# 51695               None          NaN              NaN
# 51696               None          NaN              NaN
# 51711               None          NaN              NaN
# 51784               None          NaN              NaN
#
# [3485 rows x 27 columns]

# %%
# Drop the columns 'Matched Tree Name' and 'Common Name'
merged = merged.drop(columns=['Matched Tree Name', 'Common Name'])

# %%
merged
# Out:
#         Latitude   Longitude                               Species   DBH  \
# 0      34.154814 -118.589896    coast live oak (Quercus agrifolia)  25.0
# 1      34.154815 -118.589929    coast live oak (Quercus agrifolia)  13.0
# 2      34.275480 -118.541392         MyLA311 Added (MyLA311 Added)   0.0
# 3      34.145944 -118.505713         MyLA311 Added (MyLA311 Added)   0.0
# 4      34.089382 -118.452487    coast live oak (Quercus agrifolia)  10.0
# ...          ...         ...                                   ...   ...
# 51920  34.281985 -118.524873  swamp mallee (Eucalyptus spathulata)   1.0
# 51921  34.281909 -118.524855              cork oak (Quercus suber)   1.0
# 51922  34.281829 -118.524832              cork oak (Quercus suber)   1.0
# 51923  34.281753 -118.524804              cork oak (Quercus suber)   1.0
# 51924  34.281672 -118.524785              cork oak (Quercus suber)   1.0
#
#        Any_Protected  tree_id                                       geometry  \
# 0              False      398  POINT (-118.58989569441763 34.15481399358518)
# 1              False      399  POINT (-118.5899292220234 34.154815103381026)
# 2              False      782  POINT (-118.54139204162942 34.27547960352691)
# 3              False     1620  POINT (-118.50571275517476 34.14594381558009)
# 4              False     1826  POINT (-118.4524866762754 34.089381786916896)
# ...              ...      ...                                            ...
# 51920          False   848183       POINT (-118.52487262848 34.281985493955)
# 51921          False   848184       POINT (-118.52485539633 34.281909200602)
# 51922          False   848185      POINT (-118.524831927001 34.281829415729)
# 51923          False   848186      POINT (-118.524804103646 34.281752631767)
# 51924          False   848187      POINT (-118.524785328183 34.281672292682)
#
#        index_right  OBJECTID   YEAR_  ...  GIS_ACRES    DECADES   Shape__Area  \
# 0            18162     18164  1944.0  ...  4548.5230  1950-1959  2.694018e+07
# 1            18162     18164  1944.0  ...  4548.5230  1950-1959  2.694018e+07
# 2            15796     15798  1959.0  ...   624.3035  1950-1959  3.709861e+06
# 3            15672     15674  1960.0  ...    80.7574  1960-1969  4.783674e+05
# 4            15424     15426  1961.0  ...  6151.9790  1960-1969  3.640036e+07
# ...            ...       ...     ...  ...        ...        ...           ...
# 51920        17825     17827  1947.0  ...   416.0731  1950-1959  2.472436e+06
# 51921        17825     17827  1947.0  ...   416.0731  1950-1959  2.472436e+06
# 51922        17825     17827  1947.0  ...   416.0731  1950-1959  2.472436e+06
# 51923        17825     17827  1947.0  ...   416.0731  1950-1959  2.472436e+06
# 51924        17825     17827  1947.0  ...   416.0731  1950-1959  2.472436e+06
#
#       Shape__Length  tree_appear_count  FIRE_SIZE_CATEGORY  \
# 0      35271.399924                  1               Large
# 1      35271.399924                  1               Large
# 2       8002.545419                  2              Medium
# 3       4025.625330                  1               Small
# 4      48599.914373                  1               Large
# ...             ...                ...                 ...
# 51920   7602.760800                  1              Medium
# 51921   7602.760800                  1              Medium
# 51922   7602.760800                  1              Medium
# 51923   7602.760800                  1              Medium
# 51924   7602.760800                  1              Medium
#
#       USDA_FIRE_SIZE_CLASS   TreeGroup  Annual_Temp       Firewise Rating
# 0                F - Large         Oak         62.2  AT RISK Firewise (3)
# 1                F - Large         Oak         62.2  AT RISK Firewise (3)
# 2               E - Medium     Myla311         67.3                   NaN
# 3                C - Small     Myla311         65.6                   NaN
# 4                G - Large         Oak         65.3  AT RISK Firewise (3)
# ...                    ...         ...          ...                   ...
# 51920           E - Medium  Eucalyptus         64.1      NOT Firewise (4)
# 51921           E - Medium         Oak         64.1          Firewise (1)
# 51922           E - Medium         Oak         64.1          Firewise (1)
# 51923           E - Medium         Oak         64.1          Firewise (1)
# 51924           E - Medium         Oak         64.1          Firewise (1)
#
# [51925 rows x 25 columns]

# %%
merged.to_csv('la_fire_tree_temp_score.csv', index=False)
